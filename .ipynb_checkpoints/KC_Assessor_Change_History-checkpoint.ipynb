# %% [markdown]
# # Change History

# %%
import pandas as pd

# %%
pd.options.display.max_rows = 200

# %%
ch = pd.read_csv('../../../downloads/EXTR_ChangeHistDetail_V.csv', encoding = 'latin')

# %%
import cats

# %%
u = cats.housing_cols

# %%
chh = ch.sample(10000)

# %%
cols = list(set(cats.keep_apts + cats.keep_res + cats.keep_condo))

# %%
# Out:
# 79

# %%
chh[chh['Attribute'].str.lower().isin(u)]
# Out:
#            Major  Minor   EventId           Id       Attribute AttributeValue  \
# 4235642   335340   4529   8775611         Land   CurrentZoning            NaN
# 34886115  770820    690   7738313  Property Id        LevyCode           6867
# 21700888  314835    220   5790942   Condo Unit         UnitLoc
# 7089009   954720   3970   9634007     Bldg 1          SqFtDeck            120
# 25641400  102304   9045   7738039  Property Id        LevyCode           2421
# ...          ...    ...       ...          ...             ...            ...
# 16757308   62206   9121    131602         Land    PcntUnusable              1
# 30965515  639090    980  16216292   Condo Unit         EndUnit              N
# 7389072   413800    590  12033193       Bldg 1    Obsolescence
# 18676326  681040     80  12719395       Bldg 1  FpFreestanding
# 23674553     100     25   1655380     Bldg 1           BldgNbr              1
#
#                     UpdateDate UpdatedBy
# ...

# %%
ch[(ch['Major'] == 639090) & (ch['Minor'] == 980)]
# Out:
#            Major  Minor   EventId                  Id            Attribute  \
# 26763     639090    980  16213561  TaxpayerPostalAddr                 City
# 66105     639090    980  16214281         Property Id              PlatLot
# 152220    639090    980  16216292          Condo Unit           PkgCarport
# 238765    639090    980  16213561  TaxpayerPostalAddr            DirSuffix
# 592074    639090    980  16213561  TaxpayerPostalAddr              Country
# 1645690   639090    980  16216292          Condo Unit            Condition
# 1660516   639090    980  16213561  TaxpayerPostalAddr                State
# 1750786   639090    980  16296432          Condo Unit         ViewMountain
# 2270246   639090    980  16214281         Property Id            PlatBlock
# 2726810   639090    980  16214281         Property Id         Neighborhood
# 3721178   639090    980  16214281         Property Id             PropType
# ...

# %%
ch.sample(50)
# Out:
#            Major  Minor   EventId              Id         Attribute  \
# 22120301  128830     30  14402987            Land   BaseLandValDate
# 18252149  247337    570   4396091            Land   BaseLandValUnit
# 38020925  954510     90  14618809          Bldg 1        HeatSystem
# 36467824  335640   5205  13564894     Property Id          LevyCode
# 18657122   79500   2140  10217873            Land   BaseLandValUnit
# 17715562  432250     30   1550636            Land       BaseLandVal
# 9224273   262205   9063   2685537            Land  BaseLandValTaxYr
# 14389112  179390     90  14419443          Bldg 1         Condition
# 20487634  789320   7670    382977        Bldg 1           AddnlCost
# 31168135  936570    181  15597000      Inspection         UpdatedBy
# 12621992  192405   9087  16175152        MISC IMP        UpdateDate
# 33780510  785661    530  14456711      Inspection     InspectedDate
# 20871549   92304   9368  15156886            Land         UpdatedBy
# ...

# %%
ch[(ch['Major'] == '006600') & (ch['Minor'] == '0035')]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [Major, Minor, EventId, Id, Attribute, AttributeValue, UpdateDate, UpdatedBy]
# Index: []

# %%
from con import con

# %%
ch.to_sql('changes_d', con, chunksize=500)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-53a67395b061> in <module>
# ----> 1 ch.to_sql('changes_d', con, chunksize=500)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ...
